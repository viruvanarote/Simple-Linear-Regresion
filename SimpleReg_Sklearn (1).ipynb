# %%
## Linear Regression

import numpy as np
import pandas as pd

df = pd.read_csv("d:\Hours.csv")

print(df)


X = df.iloc[:,:-1]

print(X)


y = df.iloc[:,1]

print(y)

from sklearn import linear_model


from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state = 0)


print(X_train)


print(X_test)



print(y_test)

print(y_train)


from sklearn.linear_model import LinearRegression


regressor = LinearRegression()


regressor.fit(X_train,y_train)


print(regressor.intercept_)

print(regressor.coef_)

y_pred = regressor.predict(X_test)

print(y_pred)

new = [[12]]
regressor.predict(new)
print('\npredicted value : ',regressor.predict(new))


import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.suptitle('DataSet')
plt.show()


plt.scatter(X_train,y_train)
plt.suptitle('Training Data Set')
plt.show()


plt.scatter(X_train,y_train,color = "red")  
plt.scatter(X_test,y_test,color = "blue")
plt.suptitle('predicted data')
plt.plot(X_test,y_pred,color = "green")
plt.show()

plt.suptitle('Line of Regression')
plt.scatter(X_train,y_train,color = "black")
plt.scatter(X_test,y_test,color = "blue")
plt.plot(X,regressor.predict(X),color = "green")
plt.show()
# Out:
#    Hours  Risk
# 0     10    95
# 1      9    80
# 2      2    10
# 3     15    50
# 4     10    45
# 5     16    98
# 6     11    38
# 7     16    93
#    Hours
# 0     10
# 1      9
# 2      2
# 3     15
# 4     10
# 5     16
# 6     11
# 7     16
# 0    95
# 1    80
# 2    10
# 3    50
# 4    45
# 5    98
# 6    38
# 7    93
# Name: Risk, dtype: int64
#    Hours
# 7     16
# 3     15
# 0     10
# 5     16
# 4     10
#    Hours
# 6     11
# 2      2
# 1      9
# 6    38
# 2    10
# 1    80
# Name: Risk, dtype: int64
# 7    93
# 3    50
# 0    95
# 5    98
# 4    45
# Name: Risk, dtype: int64
# 41.811224489795926
# [2.56632653]
# [70.04081633 46.94387755 64.90816327]
#
# predicted value :  [72.60714286]
